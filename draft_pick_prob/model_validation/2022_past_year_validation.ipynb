# %%
import sys
import os
import pandas as pd
import numpy as np
import pymc

sys.path.append(f'{os.path.dirname(os.path.dirname(os.getcwd()))}/draft_pick_prob')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import sys
#       <a href='vscode-notebook-cell:/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import os
# ----> <a href='vscode-notebook-cell:/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
# ...

# %%
draft_df=pd.read_csv('/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/2022_draft_order.csv')
mock_draft_df=pd.read_csv('/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/2022_EP_final_rankings.csv').rename(columns={'RANK':'RANK_EP_22'})
mock_draft_df_2=pd.read_csv('/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/2022_FC_final_rankings.csv').rename(columns={'RANK':'RANK_FC_22'})
mock_draft_df_3=pd.read_csv('/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/2022_MH_final_rankings.csv').rename(columns={'RANK':'RANK_MH_22'})


'''

mock_draft_df_3=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/JUNE_22_2023_MCKENZIE_MOCK.csv').rename(columns={'RANK':'RANK_MCKENZIE_JUNE_22'})
mock_draft_df_4=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/EP_FINAL_RANKING.csv').rename(columns={'RANK':'RANK_EP_FINAL'})
mock_draft_df_5=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/FC_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_FC_FINAL'})
mock_draft_df_6=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/MH_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_MH_FINAL'})
mock_draft_df_7=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/MP_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_MP_FINAL'})
mock_draft_df_8=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/RS_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_RS_FINAL'})
mock_draft_df_9=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/SS_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_SS_FINAL'})
mock_draft_df_10=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/DH_FINAL_RANKINGS.csv').rename(columns={'RANK':'RANK_DH_FINAL'})
mock_draft_df_11=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/Jun_1_2023_Pronman_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_JUNE_1'})
mock_draft_df_12=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/Jun_8_2023_staff_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_JUNE_8'})
mock_draft_df_13=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/Jun_14_2023_PronmanWheeler_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_WHEELER_JUNE_14'})
mock_draft_df_14=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/Jun_21_2023_Pronman_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_JUNE_21'})
mock_draft_df_15=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/Jun_27_2023_Wheeler_mockdraft.csv').rename(columns={'RANK':'RANK_WHEELER_JUNE_27'})
mock_draft_df_16=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/JUNE_13_2023_WHEELER.csv').rename(columns={'RANK':'RANK_WHEELER_JUNE_13'})
mock_draft_df_17=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/June_14_2023_staff_mockdraft.csv').rename(columns={'RANK':'RANK_STAFF_JUNE_14'})
mock_draft_df_18=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/May_8_2023_Pronman_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_MAY_8'})
mock_draft_df_19=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/May_10_2023_Wheeler_mockdraft.csv').rename(columns={'RANK':'RANK_WHEELER_MAY_10'})
mock_draft_df_20=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/May_11_2023_Pronman_mockdraft.csv').rename(columns={'RANK':'RANK_PRONMAN_MAY_11'})
mock_draft_df_21=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/draft_pick_prob/mock_drafts/2023/MAY_30_2023_PRONMAN_MOCK.csv').rename(columns={'RANK':'RANK_PRONMAN_MAY_30'})
possible_players=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/PLAYER_IDS.csv')
'''
possible_players=pd.read_csv('Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/2022PLAYER_IDS.csv')

# %%
import math
df_player_rankings=possible_players[['PLAYER_ID']].merge(mock_draft_df[['PLAYER_ID','RANK_EP_22']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_2[['PLAYER_ID','RANK_FC_22']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_3[['PLAYER_ID','RANK_MH_22']], how='left', on=['PLAYER_ID'])

'''
df_player_rankings=df_player_rankings.merge(mock_draft_df_4[['PLAYER_ID','RANK_EP_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_5[['PLAYER_ID','RANK_FC_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_6[['PLAYER_ID','RANK_MH_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_7[['PLAYER_ID','RANK_MP_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_8[['PLAYER_ID','RANK_RS_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_9[['PLAYER_ID','RANK_SS_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_10[['PLAYER_ID','RANK_DH_FINAL']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_11[['PLAYER_ID','RANK_PRONMAN_JUNE_1']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_12[['PLAYER_ID','RANK_PRONMAN_JUNE_8']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_13[['PLAYER_ID','RANK_PRONMAN_WHEELER_JUNE_14']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_14[['PLAYER_ID','RANK_PRONMAN_JUNE_21']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_15[['PLAYER_ID','RANK_WHEELER_JUNE_27']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_16[['PLAYER_ID','RANK_WHEELER_JUNE_13']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_17[['PLAYER_ID','RANK_STAFF_JUNE_14']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_18[['PLAYER_ID','RANK_PRONMAN_MAY_8']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_19[['PLAYER_ID','RANK_WHEELER_MAY_10']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_20[['PLAYER_ID','RANK_PRONMAN_MAY_11']], how='left', on=['PLAYER_ID'])
df_player_rankings=df_player_rankings.merge(mock_draft_df_21[['PLAYER_ID','RANK_PRONMAN_MAY_30']], how='left', on=['PLAYER_ID'])
'''
df_player_rankings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import math
# ----> <a href='vscode-notebook-cell:/Users/tiffanieli/Documents/EMSF_CAPSTONE/draft_pick_prob/model_validation/past_year_validation.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df_player_rankings=possible_players[['PLAYER_ID']].merge(mock_draft_df[['PLAYER_ID','RANK_EP_22']], how='left', on=['PLAYER_ID'])
# ...

# %%
def likelihood(strengths, rankings):
    # params: vector of parameters [intercept, slope]
    likelihood=1
    counter=1
    paired_lists = list(zip(strengths, rankings))
    sorted_pairs = sorted(paired_lists, key=lambda x: x[1])
    sorted_list1, sorted_list2 = zip(*sorted_pairs)
    while counter<len(sorted_list2)+1 and sorted_list2[counter]!=sorted_list2[counter+1]:
        # print(np.exp(sorted_list1[counter-1]))
        # print(np.sum(np.exp(sorted_list1[counter-1:])))
        # print(np.exp(sorted_list1[counter-1])/np.sum(np.exp(sorted_list1[counter-1:])))
        likelihood+=np.log(np.exp(sorted_list1[counter-1])/np.sum(np.exp(sorted_list1[counter-1:])))
        counter+=1
    return likelihood

def neg_log_likelihood(params, df):
    neg_ll=1
    columns_to_go_through=df.columns[1:]
    for i in columns_to_go_through:
        max=df[i].max()+1
        player_rank=list(df[i])
        fixed_player_rank=[max if math.isnan(x) else x for x in player_rank]
        neg_ll-=likelihood(params, fixed_player_rank)
    return neg_ll

# %%
def constraint_eq(x):
    return sum(x)

# %%
import scipy.optimize

counter=40
l_play=[]
variable_bounds=[]
count=0

while count<len(df_player_rankings):
    l_play.append(counter)
    count+=1
    counter-=0.20
    variable_bounds.append((-40,40))

result = scipy.optimize.minimize(neg_log_likelihood, l_play, args=(df_player_rankings,), method='SLSQP', bounds=variable_bounds, constraints={'type': 'eq', 'fun': constraint_eq})
print(result.x)
# Out:
# [ 3.92194782e+01  2.48741990e+01  2.18112280e+01  2.13208968e+01
#   1.83799572e+01  1.87671066e+01  1.86832392e+01  2.03039737e+01
#   1.73261395e+01  1.60425879e+01  1.73320299e+01  1.70766437e+01
#   1.65120280e+01  1.82504920e+01  1.60994135e+01  1.68724878e+01
#   1.55871983e+01  1.73919895e+01  1.65460144e+01  1.71262057e+01
#   1.39032535e+01  1.43184028e+01  1.57984499e+01  1.52712337e+01
#   1.34944584e+01  1.32487026e+01  1.42805660e+01  1.57928698e+01
#   1.38632842e+01  1.47673595e+01  1.42300025e+01  1.30464243e+01
#   1.27007356e+01  1.45769720e+01  1.46636509e+01  1.39017554e+01
#   1.30025566e+01  1.25332185e+01  1.29231018e+01  1.18306284e+01
#   1.23213097e+01  1.33579591e+01  1.16011776e+01  1.28443122e+01
#   1.35885458e+01  1.36805887e+01  1.19110995e+01  1.17151048e+01
#   1.35011976e+01  1.18440864e+01  1.13966094e+01  1.18007856e+01
#   1.13708333e+01  1.12341226e+01  1.10124810e+01  1.14734155e+01
# ...

# %%
player_ability_parameters_df=pd.read_csv('/Users/hinayatali/Desktop/EMSF_CAPSTONE/PLAYER_IDS.csv')
player_ability_parameters_df['ABILITY_PARAMS']=result.x
player_ability_parameters_df=player_ability_parameters_df.sort_values(by='ABILITY_PARAMS', ascending=False, axis=0)
player_ability_parameters_df.head(50)
# Out:
#               PLAYER_NAME  PLAYER_ID  ABILITY_PARAMS
# 0           Connor Bedard          1       39.219478
# 1           Adam Fantilli          2       24.874199
# 2            Leo Carlsson          3       21.811228
# 3           William Smith          4       21.320897
# 7          Matvei Michkov          8       20.303974
# 5         Dalibor Dvorsky          6       18.767107
# 6            Ryan Leonard          7       18.683239
# 4        David Reinbacher          5       18.379957
# 13            Zach Benson         14       18.250492
# 17           Oliver Moore         18       17.391989
# 10         Nate Danielson         11       17.332030
# 8       Gabriel Perreault          9       17.326139
# 19   Axel Sandin Pellikka         20       17.126206
# 11           Matthew Wood         12       17.076644
# 15           Colby Barlow         16       16.872488
# 18          Brayden Yager         19       16.546014
# 12        Dmitri Simashev         13       16.512028
# ...
